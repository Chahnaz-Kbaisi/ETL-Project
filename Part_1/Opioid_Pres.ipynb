# %%
# Import Dependencies:
import pandas as pd
import os
import numpy as np
from sqlalchemy import create_engine
from config import password
from config import username

# %%
# For Table 1
Prescription_VA = os.path.join("Resources", "Opioid_Pres_VA.csv")
# For Table 2
Prescription_Retail = os.path.join("Resources", "Opioid_Retail.csv")

# %%
# Reading in data file to store into Pandas DataFrame:
# For Table 1
Prescription_VA_df = pd.read_csv("Resources/Opioid_Pres_VA.csv")
Prescription_VA_df.head()
# Out:
#     id  Percent Change  Percent Change (integer)          city  \
# 0   77        0.442374                       -44   Albuquerque
# 1    8        0.608077                       -61  Fayetteville
# 2   45        0.504930                       -50       Wichita
# 3  146        0.401380                       -40      Sheridan
# 4   58        0.493521                       -49       Detroit
#
#                          facility_name   latitude   longitude  \
# 0  Raymond G. Murphy VA Medical Center  35.055193 -106.577684
# 1       Fayetteville VA Medical Center  36.077229  -94.157046
# 2     Robert J. Dole VA Medical Center  37.679798  -97.273500
# 3           Sheridan VA Medical Center  44.826970 -106.984884
# 4    John D. Dingell VA Medical Center  42.355141  -83.060341
#
#    2012 Prescribing Rate  2012 Prescribing Rate (integer)  \
# 0               0.234439                               23
# 1               0.223217                               22
# 2               0.198012                               20
# 3               0.139492                               14
# 4               0.257321                               26
#
#    2018 Prescribing Rate  2018 Prescribing Rate (integer)  \
# 0               0.130729                               13
# 1               0.087484                                9
# 2               0.098030                               10
# 3               0.083503                                8
# 4               0.130328                               13
#
#                            point Non-VA Prescribing Rate (Regional Use)  \
# 0  POINT (-106.577684 35.055193)                                Average
# 1   POINT (-94.157046 36.077229)                                Average
# 2     POINT (-97.2735 37.679798)                                Average
# 3   POINT (-106.984884 44.82697)                                Average
# 4   POINT (-83.060341 42.355141)                                   High
#
#    state_full state_postal
# 0  New Mexico           NM
# 1    Arkansas           AR
# 2      Kansas           KS
# 3     Wyoming           WY
# 4    Michigan           MI

# %%
# Reading in data file to store into Pandas DataFrame:
# For Table 2
Prescription_Retail_df = pd.read_csv("Resources/Opioid_Retail .csv")
Prescription_Retail_df.head()
# Out:
#    Quarter  Hydrocodone  Oxycodone  Tramadol  Morphine  Fentanyl  H+O+T+M+F  \
# 0  Q4 2009     30831801   12598334   6475986   1731324   1266443   52903888
# 1  Q1 2010     30692922   12676513   6429833   1727199   1240702   52767169
# 2  Q2 2010     31554204   13282829   6694127   1792189   1274043   54597392
# 3  Q3 2010     32000678   13748219   6811394   1833943   1283203   55677437
# 4  Q4 2010     32239057   13825106   7453897   1889202   1287753   56695015
#
#    All Opioid Analgesics  ER/LA Opioid Analgesics  \
# 0               62804834                  4808919
# 1               62407792                  4727239
# 2               64359386                  4886616
# 3               65385955                  4960528
# 4               64915764                  4900668
#
#   Yearly totals (All Opioid Analgesics)  \
# 0                               No data
# 1                             257068897
# 2                             257068897
# 3                             257068897
# 4                             257068897
#
#   Yearly totals (ER/LA Opioid Analgesics) Yearly totals (H+O+T+M+F)  \
# 0                                 No data                   No data
# 1                                19475051                 219737013
# 2                                19475051                 219737013
# 3                                19475051                 219737013
# 4                                19475051                 219737013
#
#   Yearly totals (H+O)
# 0             No data
# 1           180019528
# 2           180019528
# 3           180019528
# 4           180019528

# %%
#Table 1
Prescription_VA_df['Percent Change'] = Prescription_VA_df['Percent Change'].astype(str)
Prescription_VA_df
# Out:
#       id       Percent Change  Percent Change (integer)          city  \
# 0     77            0.4423736                       -44   Albuquerque
# 1      8   0.6080770999999999                       -61  Fayetteville
# 2     45              0.50493                       -50       Wichita
# 3    146            0.4013797                       -40      Sheridan
# 4     58            0.4935213                       -49       Detroit
# ..   ...                  ...                       ...           ...
# 141   56  0.46444650000000004                       -46     Ann Arbor
# 142   35  0.24383249999999998                       -24      Danville
# 143   24            0.3283283                       -33         Miami
# 144   63            0.5688236                       -57        Biloxi
# 145   46  0.37308209999999997                       -37     Lexington
#
#                            facility_name   latitude   longitude  \
# 0    Raymond G. Murphy VA Medical Center  35.055193 -106.577684
# 1         Fayetteville VA Medical Center  36.077229  -94.157046
# 2       Robert J. Dole VA Medical Center  37.679798  -97.273500
# 3             Sheridan VA Medical Center  44.826970 -106.984884
# 4      John D. Dingell VA Medical Center  42.355141  -83.060341
# ..                                   ...        ...         ...
# 141          Ann Arbor VA Medical Center  42.287285  -83.712300
# 142           Danville VA Medical Center  40.131790  -87.592277
# 143    Bruce W. Carter VA Medical Center  25.790438  -80.216172
# 144             Biloxi VA Medical Center  30.409011  -88.947210
# 145          Lexington VA Medical Center  38.074846  -84.537606
#
#      2012 Prescribing Rate  2012 Prescribing Rate (integer)  \
# 0                 0.234439                               23
# 1                 0.223217                               22
# 2                 0.198012                               20
# 3                 0.139492                               14
# 4                 0.257321                               26
# ..                     ...                              ...
# 141               0.196718                               20
# 142               0.132022                               13
# 143               0.089850                                9
# 144               0.222566                               22
# 145               0.209130                               21
#
#      2018 Prescribing Rate  2018 Prescribing Rate (integer)  \
# 0                 0.130729                               13
# 1                 0.087484                                9
# 2                 0.098030                               10
# 3                 0.083503                                8
# 4                 0.130328                               13
# ..                     ...                              ...
# 141               0.105353                               11
# 142               0.099831                               10
# 143               0.060350                                6
# 144               0.095965                               10
# 145               0.131107                               13
#
#                                      point  \
# 0            POINT (-106.577684 35.055193)
# 1             POINT (-94.157046 36.077229)
# 2               POINT (-97.2735 37.679798)
# 3             POINT (-106.984884 44.82697)
# 4             POINT (-83.060341 42.355141)
# ..                                     ...
# 141             POINT (-83.7123 42.287285)
# 142            POINT (-87.592277 40.13179)
# 143  POINT (-80.216172 25.790438000000005)
# 144            POINT (-88.94721 30.409011)
# 145           POINT (-84.537606 38.074846)
#
#     Non-VA Prescribing Rate (Regional Use)   state_full state_postal
# 0                                  Average   New Mexico           NM
# 1                                  Average     Arkansas           AR
# 2                                  Average       Kansas           KS
# 3                                  Average      Wyoming           WY
# 4                                     High     Michigan           MI
# ..                                     ...          ...          ...
# 141                                   High     Michigan           MI
# 142                                    Low     Illinois           IL
# 143                                    Low      Florida           FL
# 144                                   High  Mississippi           MS
# 145                                Average     Kentucky           KY
#
# [146 rows x 15 columns]

# %%
#Table 2
Prescription_Retail_df['Quarter'] = Prescription_Retail_df['Quarter'].astype(str)
Prescription_Retail_df
# Out:
#     Quarter  Hydrocodone  Oxycodone  Tramadol  Morphine  Fentanyl  H+O+T+M+F  \
# 0   Q4 2009     30831801   12598334   6475986   1731324   1266443   52903888
# 1   Q1 2010     30692922   12676513   6429833   1727199   1240702   52767169
# 2   Q2 2010     31554204   13282829   6694127   1792189   1274043   54597392
# 3   Q3 2010     32000678   13748219   6811394   1833943   1283203   55677437
# 4   Q4 2010     32239057   13825106   7453897   1889202   1287753   56695015
# 5   Q1 2011     32497676   13697064   7934498   1904519   1271533   57305290
# 6   Q2 2011     32906191   13972641   8194032   1932387   1290096   58295347
# 7   Q3 2011     32970249   14129677   8461645   1959390   1296659   58817620
# 8   Q4 2011     32557588   14015327   8426827   1985884   1292906   58278532
# 9   Q1 2012     32821380   13676982   9085356   1967390   1256587   58807695
# 10  Q2 2012     32883231   13799118   9373129   2014571   1270489   59340538
# 11  Q3 2012     32621466   13714150   9556588   2021396   1267369   59180969
# 12  Q4 2012     32429704   13810577   9753897   2058168   1273738   59326084
# 13  Q1 2013     30848355   13134306   9488158   2005937   1233775   56710531
# 14  Q2 2013     31097912   13251033   9913793   2032962   1260428   57556128
# 15  Q3 2013     31081430   13310718  10096891   2060817   1267488   57817344
# 16  Q4 2013     30629191   13405070  10327890   2073818   1261975   57697944
# 17  Q1 2014     29299051   12965080  10156105   2010032   1215947   55646215
# 18  Q2 2014     29932633   13362307  10725262   2069597   1249482   57339281
# 19  Q3 2014     30088966   13641359  10396635   2089791   1256113   57472864
# 20  Q4 2014     24111897   14074835  10435370   2115022   1261672   51998796
# 21  Q1 2015     22881381   13595329   9954737   2041447   1202643   49675537
# 22  Q2 2015     23384486   14066532  10182119   2091995   1232571   50957703
#
#     All Opioid Analgesics  ER/LA Opioid Analgesics  \
# 0                62804834                  4808919
# 1                62407792                  4727239
# 2                64359386                  4886616
# 3                65385955                  4960528
# 4                64915764                  4900668
# 5                63667268                  4750490
# 6                64655990                  4778769
# 7                65093125                  4804171
# 8                64535529                  4852112
# 9                64992656                  4674487
# 10               65346051                  4702975
# 11               65030875                  4689927
# 12               65163879                  4763795
# 13               62344354                  4593200
# 14               63108593                  4660126
# 15               63279780                  4708521
# 16               63101698                  4732618
# 17               60833351                  4559309
# 18               62555737                  4689143
# 19               62699948                  4732605
# 20               58454163                  4791578
# 21               55852248                  4568297
# 22               57274927                  4660385
#
#    Yearly totals (All Opioid Analgesics)  \
# 0                                No data
# 1                              257068897
# 2                              257068897
# 3                              257068897
# 4                              257068897
# 5                              257951912
# 6                              257951912
# 7                              257951912
# 8                              257951912
# 9                              260533461
# 10                             260533461
# 11                             260533461
# 12                             260533461
# 13                             251834425
# 14                             251834425
# 15                             251834425
# 16                             251834425
# 17                             244543199
# 18                             244543199
# 19                             244543199
# 20                             244543199
# 21                               No data
# 22                               No data
#
#    Yearly totals (ER/LA Opioid Analgesics) Yearly totals (H+O+T+M+F)  \
# 0                                  No data                   No data
# 1                                 19475051                 219737013
# 2                                 19475051                 219737013
# 3                                 19475051                 219737013
# 4                                 19475051                 219737013
# 5                                 19185542                 232696789
# 6                                 19185542                 232696789
# 7                                 19185542                 232696789
# 8                                 19185542                 232696789
# 9                                 18831184                 229781947
# 10                                18831184                 229781947
# 11                                18831184                 229781947
# 12                                18831184                 229781947
# 13                                18694465                 229781947
# 14                                18694465                 229781947
# 15                                18694465                 229781947
# 16                                18694465                 229781947
# 17                                18772635                 222457156
# 18                                18772635                 222457156
# 19                                18772635                 222457156
# 20                                18772635                 222457156
# 21                                 No data                   No data
# 22                                 No data                   No data
#
#    Yearly totals (H+O)
# 0              No data
# 1            180019528
# 2            180019528
# 3            180019528
# 4            180019528
# 5            186746413
# 6            186746413
# 7            186746413
# 8            186746413
# 9            176758015
# 10           176758015
# 11           176758015
# 12           176758015
# 13           176758015
# 14           176758015
# 15           176758015
# 16           176758015
# 17           167476128
# 18           167476128
# 19           167476128
# 20           167476128
# 21             No data
# 22             No data

# %%
# Cleaning dataset and dropping any bad records for Table #1:
cleaned_Prescription_VA_df = Prescription_VA_df.dropna(how='any')
cleaned_Prescription_VA_df.head()
# Out:
#     id      Percent Change  Percent Change (integer)          city  \
# 0   77           0.4423736                       -44   Albuquerque
# 1    8  0.6080770999999999                       -61  Fayetteville
# 2   45             0.50493                       -50       Wichita
# 3  146           0.4013797                       -40      Sheridan
# 4   58           0.4935213                       -49       Detroit
#
#                          facility_name   latitude   longitude  \
# 0  Raymond G. Murphy VA Medical Center  35.055193 -106.577684
# 1       Fayetteville VA Medical Center  36.077229  -94.157046
# 2     Robert J. Dole VA Medical Center  37.679798  -97.273500
# 3           Sheridan VA Medical Center  44.826970 -106.984884
# 4    John D. Dingell VA Medical Center  42.355141  -83.060341
#
#    2012 Prescribing Rate  2012 Prescribing Rate (integer)  \
# 0               0.234439                               23
# 1               0.223217                               22
# 2               0.198012                               20
# 3               0.139492                               14
# 4               0.257321                               26
#
#    2018 Prescribing Rate  2018 Prescribing Rate (integer)  \
# 0               0.130729                               13
# 1               0.087484                                9
# 2               0.098030                               10
# 3               0.083503                                8
# 4               0.130328                               13
#
#                            point Non-VA Prescribing Rate (Regional Use)  \
# 0  POINT (-106.577684 35.055193)                                Average
# 1   POINT (-94.157046 36.077229)                                Average
# 2     POINT (-97.2735 37.679798)                                Average
# 3   POINT (-106.984884 44.82697)                                Average
# 4   POINT (-83.060341 42.355141)                                   High
#
#    state_full state_postal
# 0  New Mexico           NM
# 1    Arkansas           AR
# 2      Kansas           KS
# 3     Wyoming           WY
# 4    Michigan           MI

# %%
# Cleaning dataset and dropping any bad records for Table #2:
cleaned_Prescription_Retail_df = Prescription_Retail_df.dropna(how='any')
cleaned_Prescription_Retail_df.head()
# Out:
#    Quarter  Hydrocodone  Oxycodone  Tramadol  Morphine  Fentanyl  H+O+T+M+F  \
# 0  Q4 2009     30831801   12598334   6475986   1731324   1266443   52903888
# 1  Q1 2010     30692922   12676513   6429833   1727199   1240702   52767169
# 2  Q2 2010     31554204   13282829   6694127   1792189   1274043   54597392
# 3  Q3 2010     32000678   13748219   6811394   1833943   1283203   55677437
# 4  Q4 2010     32239057   13825106   7453897   1889202   1287753   56695015
#
#    All Opioid Analgesics  ER/LA Opioid Analgesics  \
# 0               62804834                  4808919
# 1               62407792                  4727239
# 2               64359386                  4886616
# 3               65385955                  4960528
# 4               64915764                  4900668
#
#   Yearly totals (All Opioid Analgesics)  \
# 0                               No data
# 1                             257068897
# 2                             257068897
# 3                             257068897
# 4                             257068897
#
#   Yearly totals (ER/LA Opioid Analgesics) Yearly totals (H+O+T+M+F)  \
# 0                                 No data                   No data
# 1                                19475051                 219737013
# 2                                19475051                 219737013
# 3                                19475051                 219737013
# 4                                19475051                 219737013
#
#   Yearly totals (H+O)
# 0             No data
# 1           180019528
# 2           180019528
# 3           180019528
# 4           180019528

# %%
# Filtering dataset by selecting columns needed to answer potential query for Table 1:
Prescription_VA_subset = cleaned_Prescription_VA_df[["Percent Change (integer)", "city", "2012 Prescribing Rate", "2018 Prescribing Rate", "Non-VA Prescribing Rate (Regional Use)", "state_full", "state_postal"]]
Prescription_VA_subset.head()
# Out:
#    Percent Change (integer)          city  2012 Prescribing Rate  \
# 0                       -44   Albuquerque               0.234439
# 1                       -61  Fayetteville               0.223217
# 2                       -50       Wichita               0.198012
# 3                       -40      Sheridan               0.139492
# 4                       -49       Detroit               0.257321
#
#    2018 Prescribing Rate Non-VA Prescribing Rate (Regional Use)  state_full  \
# 0               0.130729                                Average  New Mexico
# 1               0.087484                                Average    Arkansas
# 2               0.098030                                Average      Kansas
# 3               0.083503                                Average     Wyoming
# 4               0.130328                                   High    Michigan
#
#   state_postal
# 0           NM
# 1           AR
# 2           KS
# 3           WY
# 4           MI

# %%
# Filtering dataset by selecting columns needed to answer potential query for Table 2:
Prescription_Retail_subset = cleaned_Prescription_Retail_df[["Quarter", "Hydrocodone", "Oxycodone", "Tramadol", "Morphine", "Fentanyl", "H+O+T+M+F"]]
Prescription_Retail_subset.head()
# Out:
#    Quarter  Hydrocodone  Oxycodone  Tramadol  Morphine  Fentanyl  H+O+T+M+F
# 0  Q4 2009     30831801   12598334   6475986   1731324   1266443   52903888
# 1  Q1 2010     30692922   12676513   6429833   1727199   1240702   52767169
# 2  Q2 2010     31554204   13282829   6694127   1792189   1274043   54597392
# 3  Q3 2010     32000678   13748219   6811394   1833943   1283203   55677437
# 4  Q4 2010     32239057   13825106   7453897   1889202   1287753   56695015

# %%
# Renaming the subset dataframe columns Table 1:
Prescription_rate_va = Prescription_VA_subset.rename(columns={
    'Percent Change (integer)': 'percent_change',
    '2012 Prescribing Rate': '2012_prescribing_rate',
    '2018 Prescribing Rate':'2018_prescribing_rate',
    'Non-VA Prescribing Rate (Regional Use)': 'non-va_prescribing_rate'
    
})
Prescription_rate_va.head()
# Out:
#    percent_change          city  2012_prescribing_rate  2018_prescribing_rate  \
# 0             -44   Albuquerque               0.234439               0.130729
# 1             -61  Fayetteville               0.223217               0.087484
# 2             -50       Wichita               0.198012               0.098030
# 3             -40      Sheridan               0.139492               0.083503
# 4             -49       Detroit               0.257321               0.130328
#
#   non-va_prescribing_rate  state_full state_postal
# 0                 Average  New Mexico           NM
# 1                 Average    Arkansas           AR
# 2                 Average      Kansas           KS
# 3                 Average     Wyoming           WY
# 4                    High    Michigan           MI

# %%
# Renaming the subset dataframe columns Table 2:
Prescription_rate_retail = Prescription_Retail_subset.rename(columns={
    'Quarter': 'quarter',
    'Hydrocodone': 'hydrocodone',
    'Oxycodone':'oxycodone',
    'Tramadol':'tramadol',
    'Morphine':'morphine',
    'Fentanyl':'fentanyl',
    'H+O+T+M+F': 'h+o+t+m+f'
    
})
Prescription_rate_retail.head()
# Out:
#    quarter  hydrocodone  oxycodone  tramadol  morphine  fentanyl  h+o+t+m+f
# 0  Q4 2009     30831801   12598334   6475986   1731324   1266443   52903888
# 1  Q1 2010     30692922   12676513   6429833   1727199   1240702   52767169
# 2  Q2 2010     31554204   13282829   6694127   1792189   1274043   54597392
# 3  Q3 2010     32000678   13748219   6811394   1833943   1283203   55677437
# 4  Q4 2010     32239057   13825106   7453897   1889202   1287753   56695015

# %%
# Checking columns data type to see if we need to change in order to avoid errors in loading step for Table 1
Prescription_rate_va.dtypes
# Out:
# percent_change               int64
# city                        object
# 2012_prescribing_rate      float64
# 2018_prescribing_rate      float64
# non-va_prescribing_rate     object
# state_full                  object
# state_postal                object
# dtype: object

# %%
# Checking columns data type to see if we need to change in order to avoid errors in loading step for Table 1
Prescription_rate_retail.dtypes
# Out:
# quarter        object
# hydrocodone     int64
# oxycodone       int64
# tramadol        int64
# morphine        int64
# fentanyl        int64
# h+o+t+m+f       int64
# dtype: object

# %%
# load data into postgress Table 1
new_Prescription_rate_va = Prescription_rate_va[['percent_change', 'city', '2012_prescribing_rate', '2018_prescribing_rate', 'non-va_prescribing_rate', 'state_full', 'state_postal']].copy()
new_Prescription_rate_va.head()
# Out:
#    percent_change          city  2012_prescribing_rate  2018_prescribing_rate  \
# 0             -44   Albuquerque               0.234439               0.130729
# 1             -61  Fayetteville               0.223217               0.087484
# 2             -50       Wichita               0.198012               0.098030
# 3             -40      Sheridan               0.139492               0.083503
# 4             -49       Detroit               0.257321               0.130328
#
#   non-va_prescribing_rate  state_full state_postal
# 0                 Average  New Mexico           NM
# 1                 Average    Arkansas           AR
# 2                 Average      Kansas           KS
# 3                 Average     Wyoming           WY
# 4                    High    Michigan           MI

# %%
# load data into postgress Table 2
new_Prescription_rate_retail = Prescription_rate_retail[['quarter', 'hydrocodone', 'oxycodone', 'tramadol','morphine', 'fentanyl', 'h+o+t+m+f']].copy()
new_Prescription_rate_retail.head()
# Out:
#    quarter  hydrocodone  oxycodone  tramadol  morphine  fentanyl  h+o+t+m+f
# 0  Q4 2009     30831801   12598334   6475986   1731324   1266443   52903888
# 1  Q1 2010     30692922   12676513   6429833   1727199   1240702   52767169
# 2  Q2 2010     31554204   13282829   6694127   1792189   1274043   54597392
# 3  Q3 2010     32000678   13748219   6811394   1833943   1283203   55677437
# 4  Q4 2010     32239057   13825106   7453897   1889202   1287753   56695015

# %%
# Connecting to localhost database Table 1:
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/Prescription')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-145-2df5d1e90ec7> in <module>
#       1 # Connecting to localhost database Table 1:
#       2 engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/Prescription')
# ----> 3 connection = engine.connect()
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2261         """
#    2262
# -> 2263         return self._connection_cls(self, **kwargs)
#    2264
#    2265     @util.deprecated(
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     102                 connection
#     103                 if connection is not None
# --> 104                 else engine.raw_connection()
#     105             )
#     106             self.__transaction = None
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2368         """
#    2369         return self._wrap_pool_connect(
# -> 2370             self.pool.unique_connection, _connection
#    2371         )
#    2372
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2338             if connection is None:
#    2339                 Connection._handle_dbapi_exception_noconnection(
# -> 2340                     e, dialect, self
#    2341                 )
#    2342             else:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582         elif should_wrap:
#    1583             util.raise_(
# -> 1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#    1586         else:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     302
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#     306     def _create_connection(self):
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#      72         else:
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~/opt/anaconda3/envs/pam/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Reviewing the tables from SQL Database Table 1
engine.table_names()

# %%
# File 1: 
new_overdose_death.to_sql(name='overdose_death', con=engine, if_exists='append', index=False)

# %%
# File 1: 
pd.read_sql_query('select * from overdose_death', con=engine).head()

# %%
# Saving to csv for Table 1: 
#Prescription_rate_va.to_csv('Resources/Prescription_rate_va.csv', index=False)

# %%
# Saving to csv for Table 2: 
#Prescription_rate_retail.to_csv('Resources/Prescription_rate_retail.csv', index=False)

# %%
#Query from Table 1
# what is the average number of death per year and state
# Prescription_rate_va = """
#     SELECT city,
#            Prescription_rate_va per city 
#     FROM Prescription_rate_va
#     WHERE 2012 Prescribing Rate < '20';
# """
# Prescription_rate_va

# %%
# #Query fron Table 2
# #  Highest amount of hydrocodone used
# Prescription_rate_retail = """
#     SELECT hydrocodone,
#            Prescription_rate_retail per hydrocodone 
#     FROM Prescription_rate_retail
#     WHERE hydrocodone > '32000000';
# """
# Prescription_rate_retail
